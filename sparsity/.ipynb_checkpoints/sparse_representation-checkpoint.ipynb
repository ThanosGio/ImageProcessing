# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import scipy.io
from sklearn import linear_model
from sklearn import model_selection
from scipy.optimize import minimize
from skimage.transform import resize
from matplotlib.image import imread

plt.rcParams['figure.figsize'] = [7, 7]
plt.rcParams.update({'font.size': 18})

# Define the absolute path
absolute_path = r"C:\Users\thana\OneDrive\Desktop\Imageprocessing\DATA"

mustache = imread(os.path.join(absolute_path, 'mustache.jpg'))
mustache = np.mean(mustache, -1)  # Convert RGB to grayscale
mustache = (mustache / 255).astype(int)
mustache = mustache.T

mat = scipy.io.loadmat(os.path.join(absolute_path, 'allFaces.mat'))
X = mat['faces']
print(mat['faces'])
nfaces = mat['nfaces'].reshape(-1)
print(nfaces)
n = mat['n'].item()  # Extract scalar value correctly
m = mat['m'].item()  # Extract scalar value correctly
# Out:
# [[80 94 59 ...  3  4  4]
#  [81 87 67 ...  4  4  3]
#  [80 88 66 ...  2  4  4]
#  ...
#  [14  7  6 ...  0  1  1]
#  [14  9  6 ...  1  1  0]
#  [11  8  7 ...  1  1  2]]
# [64 62 64 64 62 64 64 64 64 64 60 59 60 63 62 63 63 64 64 64 64 64 64 64
#  64 64 64 64 64 64 64 64 64 64 64 64 64 64]

# %%
## Build Training and Test sets
nTrain = 30
nTest = 20
nPeople = 20
Train = np.zeros((X.shape[0],nTrain*nPeople))
Test = np.zeros((X.shape[0],nTest*nPeople))

for k in range(nPeople):
    baseind = 0
    if k > 0:
        baseind = np.sum(nfaces[:k])
    inds = range(baseind,baseind+nfaces[k])
    Train[:,k*nTrain:(k+1)*nTrain] = X[:,inds[:nTrain]]
    Test[:,k*nTest:(k+1)*nTest] = X[:,inds[nTrain:(nTrain+nTest)]]

# %%
## Build Training and Test sets
nTrain = 30
nTest = 20
nPeople = 20
Train = np.zeros((X.shape[0],nTrain*nPeople))
Test = np.zeros((X.shape[0],nTest*nPeople))

for k in range(nPeople):
    baseind = 0
    if k > 0:
        baseind = np.sum(nfaces[:k])
    inds = range(baseind,baseind+nfaces[k])
    Train[:,k*nTrain:(k+1)*nTrain] = X[:,inds[:nTrain]]
    Test[:,k*nTest:(k+1)*nTest] = X[:,inds[nTrain:(nTrain+nTest)]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 32
#      29 Theta = np.zeros((m * n, nPeople))
#      31 for k in range(nPeople):
# ---> 32     temp = np.reshape(np.copy(Train[:, k * nTrain]), (X.shape[0], nTrain))
#      33     tempSmall = resize(temp, (m, n), anti_aliasing=True)
#      34     Theta[:, k] = np.reshape(tempSmall, (m * n,))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:285, in reshape(a, newshape, order)
#     200 @array_function_dispatch(_reshape_dispatcher)
#     201 def reshape(a, newshape, order='C'):
#     202     """
#     203     Gives a new shape to an array without changing its data.
#     204
#    (...)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 32256 into shape (32256,30)

# %%
## Downsample Training Images (Build Theta)
M = Train.shape[1]

Theta = np.zeros((120,M))
for k in range(M):
    temp = np.reshape(np.copy(Train[:,k]),(m,n))
    tempSmall = resize(temp, (10, 12), anti_aliasing=True)
    Theta[:,k] = np.reshape(tempSmall,120,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#
# TypeError: order must be str, not int
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 8
#       6 temp = np.reshape(np.copy(Train[:,k]),(m,n))
#       7 tempSmall = resize(temp, (10, 12), anti_aliasing=True)
# ----> 8 Theta[:,k] = np.reshape(tempSmall,120,1)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:285, in reshape(a, newshape, order)
#     200 @array_function_dispatch(_reshape_dispatcher)
#     201 def reshape(a, newshape, order='C'):
#     202     """
#     203     Gives a new shape to an array without changing its data.
#     204
#    (...)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:68, in _wrapfunc(obj, method, *args, **kwds)
#      59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
# ---> 68     return _wrapit(obj, method, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:45, in _wrapit(obj, method, *args, **kwds)
#      43 except AttributeError:
#      44     wrap = None
# ---> 45 result = getattr(asarray(obj), method)(*args, **kwds)
#      46 if wrap:
#      47     if not isinstance(result, mu.ndarray):
#
# TypeError: order must be str, not int

# %%
## Renormalize Columns of Theta
normTheta = np.zeros(M)
for k in range(M):
    normTheta[k] = np.linalg.norm(Theta[:,k])
    Theta[:,k] = Theta[:,k]/normTheta[k]
# Out:
# C:\Users\thana\AppData\Local\Temp\ipykernel_28532\2250534597.py:5: RuntimeWarning: invalid value encountered in divide
#   Theta[:,k] = Theta[:,k]/normTheta[k]

# %%
## Occlude Test Image (Test[:,125] = test image 6, person 7)
x1 = np.copy(Test[:,125]) # Clean image
x2 = np.copy(Test[:,125]) * mustache.reshape(n*m)
randvec = np.random.permutation(n*m)
first30 = randvec[:int(np.floor(0.3*len(randvec)))]
vals30 = (255*np.random.rand(*first30.shape)).astype(int)
x3 = np.copy(x1)
x3[first30] = vals30 # 30% occluded
x4 = np.copy(x1) + 50*np.random.randn(*x1.shape) # Random noise

# %%
## Downsample Test Images
X = np.zeros((x1.shape[0],4))
X[:,0] = x1
X[:,1] = x2
X[:,2] = x3
X[:,3] = x4

Y = np.zeros((120,4))
for k in range(4):
    temp = np.reshape(np.copy(X[:,k]),(m,n))
    tempSmall = resize(temp, (10, 12), anti_aliasing=True)
    Y[:,k] = np.reshape(tempSmall,120,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#
# TypeError: order must be str, not int
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 12
#      10 temp = np.reshape(np.copy(X[:,k]),(m,n))
#      11 tempSmall = resize(temp, (10, 12), anti_aliasing=True)
# ---> 12 Y[:,k] = np.reshape(tempSmall,120,1)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:285, in reshape(a, newshape, order)
#     200 @array_function_dispatch(_reshape_dispatcher)
#     201 def reshape(a, newshape, order='C'):
#     202     """
#     203     Gives a new shape to an array without changing its data.
#     204
#    (...)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:68, in _wrapfunc(obj, method, *args, **kwds)
#      59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
# ---> 68     return _wrapit(obj, method, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:45, in _wrapit(obj, method, *args, **kwds)
#      43 except AttributeError:
#      44     wrap = None
# ---> 45 result = getattr(asarray(obj), method)(*args, **kwds)
#      46 if wrap:
#      47     if not isinstance(result, mu.ndarray):
#
# TypeError: order must be str, not int

# %%
## L1 Search, Testclean
y1 = np.copy(Y[:,0])
eps = 0.01

# L1 Minimum norm solution s_L1
def L1_norm(x):
    return np.linalg.norm(x,ord=1)

constr = ({'type': 'ineq', 'fun': lambda x:  eps - np.linalg.norm(Theta @ x - y1,2)})
x0 = np.linalg.pinv(Theta) @ y1 # initialize with L2 solution
res = minimize(L1_norm, x0, method='SLSQP',constraints=constr)
s1 = res.x
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[12], line 10
#       7     return np.linalg.norm(x,ord=1)
#       9 constr = ({'type': 'ineq', 'fun': lambda x:  eps - np.linalg.norm(Theta @ x - y1,2)})
# ---> 10 x0 = np.linalg.pinv(Theta) @ y1 # initialize with L2 solution
#      11 res = minimize(L1_norm, x0, method='SLSQP',constraints=constr)
#      12 s1 = res.x
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:2022, in pinv(a, rcond, hermitian)
#    2020     return wrap(res)
#    2021 a = a.conjugate()
# -> 2022 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2024 # discard small singular values
#    2025 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#    1678         gufunc = _umath_linalg.svd_n_s
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1682 u = u.astype(result_t, copy=False)
#    1683 s = s.astype(_realType(result_t), copy=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:121, in _raise_linalgerror_svd_nonconvergence(err, flag)
#     120 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 121     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %%
plt.figure()
plt.plot(s1)
plt.figure()
plt.imshow(np.reshape(Train @ (s1/normTheta),(m,n)).T,cmap='gray')
plt.figure()
plt.imshow(np.reshape(x1 - Train @ (s1/normTheta),(m,n)).T,cmap='gray')

binErr = np.zeros(nPeople)
for k in range(nPeople):
    L = range(k*nTrain,(k+1)*nTrain)
    binErr[k] = np.linalg.norm(x1-Train[:,L] @ (s1[L]/normTheta[L]))/np.linalg.norm(x1)
    
plt.figure()
plt.bar(range(nPeople),binErr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.figure()
# ----> 2 plt.plot(s1)
#       3 plt.figure()
#       4 plt.imshow(np.reshape(Train @ (s1/normTheta),(m,n)).T,cmap='gray')
#
# NameError: name 's1' is not defined

# %%
## L1 Search, Mustache
y2 = np.copy(Y[:,1])
eps = 500

# L1 Minimum norm solution s_L1
def L1_norm(x):
    return np.linalg.norm(x,ord=1)

constr = ({'type': 'ineq', 'fun': lambda x:  eps - np.linalg.norm(Theta @ x - y2,2)})
x0 = np.linalg.pinv(Theta) @ y2 # initialize with L2 solution
res = minimize(L1_norm, x0, method='SLSQP',constraints=constr)
s2 = res.x
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[14], line 10
#       7     return np.linalg.norm(x,ord=1)
#       9 constr = ({'type': 'ineq', 'fun': lambda x:  eps - np.linalg.norm(Theta @ x - y2,2)})
# ---> 10 x0 = np.linalg.pinv(Theta) @ y2 # initialize with L2 solution
#      11 res = minimize(L1_norm, x0, method='SLSQP',constraints=constr)
#      12 s2 = res.x
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:2022, in pinv(a, rcond, hermitian)
#    2020     return wrap(res)
#    2021 a = a.conjugate()
# -> 2022 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2024 # discard small singular values
#    2025 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#    1678         gufunc = _umath_linalg.svd_n_s
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1682 u = u.astype(result_t, copy=False)
#    1683 s = s.astype(_realType(result_t), copy=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:121, in _raise_linalgerror_svd_nonconvergence(err, flag)
#     120 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 121     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %%
plt.figure()
plt.plot(s2)
plt.figure()
plt.imshow(np.reshape(Train @ (s2/normTheta),(m,n)).T,cmap='gray')
plt.figure()
plt.imshow(np.reshape(x2 - Train @ (s2/normTheta),(m,n)).T,cmap='gray')

binErr = np.zeros(nPeople)
for k in range(nPeople):
    L = range(k*nTrain,(k+1)*nTrain)
    binErr[k] = np.linalg.norm(x2-Train[:,L] @ (s2[L]/normTheta[L]))/np.linalg.norm(x2)
    
plt.figure()
plt.bar(range(nPeople),binErr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 plt.figure()
# ----> 2 plt.plot(s2)
#       3 plt.figure()
#       4 plt.imshow(np.reshape(Train @ (s2/normTheta),(m,n)).T,cmap='gray')
#
# NameError: name 's2' is not defined

# %%
## L1 Search, Occlusion
y3 = np.copy(Y[:,2])
eps = 1000

# L1 Minimum norm solution s_L1
def L1_norm(x):
    return np.linalg.norm(x,ord=1)

constr = ({'type': 'ineq', 'fun': lambda x:  eps - np.linalg.norm(Theta @ x - y3,2)})
x0 = np.linalg.pinv(Theta) @ y3 # initialize with L2 solution
res = minimize(L1_norm, x0, method='SLSQP',constraints=constr)
s3 = res.x
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[16], line 10
#       7     return np.linalg.norm(x,ord=1)
#       9 constr = ({'type': 'ineq', 'fun': lambda x:  eps - np.linalg.norm(Theta @ x - y3,2)})
# ---> 10 x0 = np.linalg.pinv(Theta) @ y3 # initialize with L2 solution
#      11 res = minimize(L1_norm, x0, method='SLSQP',constraints=constr)
#      12 s3 = res.x
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:2022, in pinv(a, rcond, hermitian)
#    2020     return wrap(res)
#    2021 a = a.conjugate()
# -> 2022 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2024 # discard small singular values
#    2025 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#    1678         gufunc = _umath_linalg.svd_n_s
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1682 u = u.astype(result_t, copy=False)
#    1683 s = s.astype(_realType(result_t), copy=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:121, in _raise_linalgerror_svd_nonconvergence(err, flag)
#     120 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 121     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %%
plt.figure()
plt.plot(s3)
plt.figure()
plt.imshow(np.reshape(Train @ (s3/normTheta),(m,n)).T,cmap='gray')
plt.figure()
plt.imshow(np.reshape(x3 - Train @ (s3/normTheta),(m,n)).T,cmap='gray')

binErr = np.zeros(nPeople)
for k in range(nPeople):
    L = range(k*nTrain,(k+1)*nTrain)
    binErr[k] = np.linalg.norm(x3-Train[:,L] @ (s3[L]/normTheta[L]))/np.linalg.norm(x3)
    
plt.figure()
plt.bar(range(nPeople),binErr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 plt.figure()
# ----> 2 plt.plot(s3)
#       3 plt.figure()
#       4 plt.imshow(np.reshape(Train @ (s3/normTheta),(m,n)).T,cmap='gray')
#
# NameError: name 's3' is not defined

# %%
## L1 Search, Noise
y4 = np.copy(Y[:,3])
eps = 10

# L1 Minimum norm solution s_L1
def L1_norm(x):
    return np.linalg.norm(x,ord=1)

constr = ({'type': 'ineq', 'fun': lambda x:  eps - np.linalg.norm(Theta @ x - y4,2)})
x0 = np.linalg.pinv(Theta) @ y4 # initialize with L2 solution
res = minimize(L1_norm, x0, method='SLSQP',constraints=constr)
s4 = res.x
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[18], line 10
#       7     return np.linalg.norm(x,ord=1)
#       9 constr = ({'type': 'ineq', 'fun': lambda x:  eps - np.linalg.norm(Theta @ x - y4,2)})
# ---> 10 x0 = np.linalg.pinv(Theta) @ y4 # initialize with L2 solution
#      11 res = minimize(L1_norm, x0, method='SLSQP',constraints=constr)
#      12 s4 = res.x
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:2022, in pinv(a, rcond, hermitian)
#    2020     return wrap(res)
#    2021 a = a.conjugate()
# -> 2022 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2024 # discard small singular values
#    2025 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#    1678         gufunc = _umath_linalg.svd_n_s
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1682 u = u.astype(result_t, copy=False)
#    1683 s = s.astype(_realType(result_t), copy=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:121, in _raise_linalgerror_svd_nonconvergence(err, flag)
#     120 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 121     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %%
plt.figure()
plt.plot(s4)
plt.figure()
plt.imshow(np.reshape(Train @ (s4/normTheta),(m,n)).T,cmap='gray')
plt.figure()
plt.imshow(np.reshape(x4 - Train @ (s4/normTheta),(m,n)).T,cmap='gray')

binErr = np.zeros(nPeople)
for k in range(nPeople):
    L = range(k*nTrain,(k+1)*nTrain)
    binErr[k] = np.linalg.norm(x4-Train[:,L] @ (s4[L]/normTheta[L]))/np.linalg.norm(x4)
    
plt.figure()
plt.bar(range(nPeople),binErr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 plt.figure()
# ----> 2 plt.plot(s4)
#       3 plt.figure()
#       4 plt.imshow(np.reshape(Train @ (s4/normTheta),(m,n)).T,cmap='gray')
#
# NameError: name 's4' is not defined

# %%
## Least Squares Is No Good
s4L2 = np.linalg.pinv(Train) @ x4
plt.figure()
plt.plot(s4L2)
plt.figure()
plt.imshow(np.reshape(Train @ (s4L2/normTheta),(m,n)).T,cmap='gray')
plt.figure()
plt.imshow(np.reshape(x4 - Train @ (s4L2/normTheta),(m,n)).T,cmap='gray')

binErr = np.zeros(nPeople)
for k in range(nPeople):
    L = range(k*nTrain,(k+1)*nTrain)
    binErr[k] = np.linalg.norm(x4-Train[:,L] @ (s4L2[L]/normTheta[L]))/np.linalg.norm(x4)
    
plt.figure()
plt.bar(range(nPeople),binErr)
plt.show()
# Out:
# C:\Users\thana\AppData\Local\Temp\ipykernel_28532\3528801694.py:6: RuntimeWarning: divide by zero encountered in divide
#   plt.imshow(np.reshape(Train @ (s4L2/normTheta),(m,n)).T,cmap='gray')
# C:\Users\thana\AppData\Local\Temp\ipykernel_28532\3528801694.py:6: RuntimeWarning: invalid value encountered in matmul
#   plt.imshow(np.reshape(Train @ (s4L2/normTheta),(m,n)).T,cmap='gray')
# C:\Users\thana\AppData\Local\Temp\ipykernel_28532\3528801694.py:8: RuntimeWarning: divide by zero encountered in divide
#   plt.imshow(np.reshape(x4 - Train @ (s4L2/normTheta),(m,n)).T,cmap='gray')
# C:\Users\thana\AppData\Local\Temp\ipykernel_28532\3528801694.py:8: RuntimeWarning: invalid value encountered in matmul
#   plt.imshow(np.reshape(x4 - Train @ (s4L2/normTheta),(m,n)).T,cmap='gray')
# C:\Users\thana\AppData\Local\Temp\ipykernel_28532\3528801694.py:13: RuntimeWarning: divide by zero encountered in divide
#   binErr[k] = np.linalg.norm(x4-Train[:,L] @ (s4L2[L]/normTheta[L]))/np.linalg.norm(x4)
# C:\Users\thana\AppData\Local\Temp\ipykernel_28532\3528801694.py:13: RuntimeWarning: invalid value encountered in matmul
#   binErr[k] = np.linalg.norm(x4-Train[:,L] @ (s4L2[L]/normTheta[L]))/np.linalg.norm(x4)
